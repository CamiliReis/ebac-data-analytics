# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exerc%C3%ADcios/Exerc%C3%ADcio3_Compara%C3%A7%C3%A3o_de_idade_(operadores_relacionais_e_l%C3%B3gicos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 3 — Comparação de idade (operadores relacionais e lógicos)

# %%
idade= int(input("Qual sua idade?: "))
print(f"Tenho {idade} anos")
print("A pessoa é maior de idade?" , idade>=18)
print("A pessoa está em idade ativa de trabalho?" , idade>=18 and idade<=65)
print()

print("Tipo da variavel idade:", type(idade))
# Out:
# Qual sua idade?: 22
# Tenho 22 anos
# A pessoa é maior de idade? True
# A pessoa está em idade ativa de trabalho? True
#
# Tipo da variavel idade: <class 'int'>
