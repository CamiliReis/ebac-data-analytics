# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exerc%C3%ADcios/Exerc%C3%ADcio5_Sal%C3%A1rio_e_idade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 5 — Salário e idade

# %%
idade= int(input("Qual sua idade?: "))
print(f"Minha idade é: {idade} anos")
print()

salario= float(input("Qual o valor da sua renda mensal?:"))
print(f"Minha renda mensal é de R$ {salario:.2f}")
print()

print("A pessoa é maior de idade?" , idade>=18)
print("O salario é 2 mil ou acima?" , salario>= 2000)
print("É maior de idade e ganha pelo menos 2 mil?" , idade>= 18 and salario>=2000)
# Out:
# Qual sua idade?: 22
# Minha idade é: 22 anos
#
# Qual o valor da sua renda mensal?:2352
# Minha renda mensal é de R$ 2352.00
#
# A pessoa é maior de idade? True
# O salario é 2 mil ou acima? True
# É maior de idade e ganha pelo menos 2 mil? True
