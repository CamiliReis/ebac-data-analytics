# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exerc%C3%ADcios/Exerc%C3%ADcio1_Cadastro_b%C3%A1sico_do_usu%C3%A1rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1 — Cadastro básico do usuário

# %%
nome= input("Digite seu nome: ")
print("Meu nome é, ", nome)
print()

idade= int(input("Digite sua idade: "))
print(f"Eu tenho {idade} anos")
print()

altura= float(input("Digite sua altura: "))
print(f"Minha altura é {altura}")
print()

print("Tipo da variável nome:", type(nome))
print("Tipo da variável idade:", type(idade))
print("Tipo da variável altura:", type(altura))
# Out:
# Digite seu nome: Camili Reis
# Meu nome é,  Camili Reis
#
# Digite sua idade: 22
# Eu tenho 22 anos
#
# Digite sua altura: 1.65
# Minha altura é 1.65
#
# Tipo da variável nome: <class 'str'>
# Tipo da variável idade: <class 'int'>
# Tipo da variável altura: <class 'float'>
