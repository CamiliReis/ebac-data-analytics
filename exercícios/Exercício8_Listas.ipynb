# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exerc%C3%ADcios/Exerc%C3%ADcio8_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 8 - Listas

# %%
frutas = ["maçã", "banana", "laranja", "uva"]
frutas[3]
# Out:
# 'uva'
