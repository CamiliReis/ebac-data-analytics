# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exercicios/Exercicios_Basicos_Python_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 1 — Cadastro básico do usuário

# %%
nome= input("Digite seu nome: ")
print("Meu nome é, ", nome)
print()

idade= int(input("Digite sua idade: "))
print(f"Eu tenho {idade} anos")
print()

altura= float(input("Digite sua altura: "))
print(f"Minha altura é {altura}")
print()

print("Tipo da variável nome:", type(nome))
print("Tipo da variável idade:", type(idade))
print("Tipo da variável altura:", type(altura))

# %% [markdown]
# # Exercício 2 — Cálculo de desconto em uma compra

# %%
camiseta= float(input("Qual o valor da camiseta?: "))
print(f"Valor: R$ {camiseta:.2f}")
print()

desconto = float(input("Qual o percentual de desconto?: "))
print(f"Valor do desconto %: {desconto}")
print()

desconto_decimal= desconto/100

valor_desconto= camiseta * desconto_decimal

valor_final= camiseta-valor_desconto

print(f"Valor do desconto em reais: R$ {valor_desconto:.2f}")
print()

print(f"Valor final: R$ {valor_final:.2f}")
print()

print("Tipo da variável camiseta:", type(camiseta))
print("Tipo da variável desconto:", type(desconto))
# Out:
# Qual o valor da camiseta?: 2222
# Valor: R$ 2222.00
#
# Qual o percentual de desconto?: 22
# Valor do desconto %: 22.0
#
# Valor do desconto em reais: R$ 488.84
#
# Valor final: R$ 1733.16
#
# Tipo da variável camiseta: <class 'float'>
# Tipo da variável desconto: <class 'float'>

# %% [markdown]
# # Exercício 3 — Comparação de idade (operadores relacionais e lógicos)

# %%
idade= int(input("Qual sua idade?: "))
print(f"Tenho {idade} anos")
print("A pessoa é maior de idade?" , idade>=18)
print("A pessoa está em idade ativa de trabalho?" , idade>=18 and idade<=65)
print()

print("Tipo da variavel idade:", type(idade))

# %% [markdown]
# # Mini-desafio 1 — Média de notas

# %%
nota_portugues= float(input("Qual sua nota em portugues?: "))
print(f"Minha nota em portugues é {nota_portugues}")
print()

nota_matematica= float(input("Qual sua nota em matemática?: "))
print(f"Miha nota em matemática é {nota_matematica}")
print()

media_notas= (nota_portugues + nota_matematica) / 2
print(f"A média das notas é: {media_notas}")
print()

print(media_notas>=6)

# %% [markdown]
# #Mini-desafio 2 — Salário e idade

# %%
idade= int(input("Qual sua idade?: "))
print(f"Minha idade é: {idade} anos")
print()

salario= float(input("Qual o valor da sua renda mensal?:"))
print(f"Minha renda mensal é de R$ {salario:.2f}")
print()

print("A pessoa é maior de idade?" , idade>=18)
print("O salario é 2 mil ou acima?" , salario>= 2000)
print("É maior de idade e ganha pelo menos 2 mil?" , idade>= 18 and salario>=2000)

# %% [markdown]
# # Mini-desafio 3 — Conversor simples

# %%
real_brasileiro= float(input("Qual o valor em reais?: "))
print(f"O valor em Reais é: R$ {real_brasileiro:.2f}")

cotacao_dolar= 5

valor_dolar = real_brasileiro / cotacao_dolar
print(f"O valor em dólar é: US$ {valor_dolar:.2f}")

# %% [markdown]
# # Verificação de senha simples

# %%
# Definir a senha permitida
senha_permitida = "12345"
# Solicitar a senha do usuário
senha_usuario = input("Digite a senha: ")
# Verificar se a senha está correta
if senha_usuario == senha_permitida:
  print("Acesso permitido!")
else:
  print("Senha incorreta. Acesso negado.")
# Out:
# Digite a senha: ddddd
# Senha incorreta. Acesso negado.

# %% [markdown]
# # listas

# %%
frutas = ["maçã", "banana", "laranja", "uva"]
frutas[3]
# Out:
# 'uva'

# %% [markdown]
# # Organizando dados de feedback de clientes

# %%
# Lista de feedbacks
feedbacks = ["Ótimo serviço!", "Produto excelente", "Atendimento rápido"]

# Dicionário com informações de um cliente
cliente = {
    "nome": "Maria",
    "idade": 28,
    "feedback": "Muito satisfeita"
}

# Imprimir os feedbacks da lista
print("Feedbacks dos clientes:")
for feedback in feedbacks:
    print("- " + feedback)

# Imprimir informações do cliente
print("\nInformações do cliente:")
print("Nome:", cliente["nome"])
print("Idade:", cliente["idade"])
print("Feedback:", cliente["feedback"])
# Out:
# Feedbacks dos clientes:
# - Ótimo serviço!
# - Produto excelente
# - Atendimento rápido
#
# Informações do cliente:
# Nome: Maria
# Idade: 28
# Feedback: Muito satisfeita

# %% [markdown]
# # Aplicando estruturas de repetição (exercicio pratico)

# %%
# Lista de notas dos alunos
notas = [85, 92, 78, 90, 88]

# Calcula a média das notas
soma = 0
for nota in notas:
    soma += nota

media = soma / len(notas)

# Classifica os alunos com base na média
alunos_aprovados = []
alunos_reprovados = []

for nota in notas:
    if nota >= media:
        alunos_aprovados.append(nota)
    else:
        alunos_reprovados.append(nota)

# Imprime os resultados
print("Notas dos alunos:", notas)
print("Média das notas:", media)
print("Alunos aprovados:", alunos_aprovados)
print("Alunos reprovados:", alunos_reprovados)
# Out:
# Notas dos alunos: [85, 92, 78, 90, 88]
# Média das notas: 86.6
# Alunos aprovados: [92, 90, 88]
# Alunos reprovados: [85, 78]

# %% [markdown]
# # EXERCÍCIOS — Estruturas Condicionais (if / else / elif)

# %%
idade= int(input("Digite sua idade: "))
print(f"Minha idade é: {idade} anos")
if idade >= 18:
  print("Maior de idade")
else:
  print("Menor de idade")
# Out:
# Digite sua idade: 15
# Minha idade é: 15 anos
# Menor de idade

# %%
nota= float(input("Digite sua nota: "))
print(f"Minha nota é: {nota}")
if nota >=7:
  print("Aprovado")
elif nota>= 5:
  print("Recuperação")
else:
  print("Reprovado")
# Out:
# Digite sua nota: 8
# Minha nota é: 8.0
# Aprovado

# %% [markdown]
# # Criando listas de numeros

# %%
#Criando listas de numeros

numeros= ["2022","2023","2024","2025","2026"]
for numero in numeros:
  print(numeros [4])
# Out:
# 2026
# 2026
# 2026
# 2026
# 2026
