# %% [markdown]
# <a href="https://colab.research.google.com/github/CamiliReis/ebac-data-analytics/blob/main/exerc%C3%ADcio/Exerc%C3%ADcio7_Verifica%C3%A7%C3%A3o_de_senha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício 7 — Verificação de senha simples

# %%
# Definir a senha permitida
senha_permitida = "12345"
# Solicitar a senha do usuário
senha_usuario = input("Digite a senha: ")
# Verificar se a senha está correta
if senha_usuario == senha_permitida:
  print("Acesso permitido!")
else:
  print("Senha incorreta. Acesso negado.")
# Out:
# Digite a senha: 12345
# Acesso permitido!
